# %% [markdown]
# ## Mission 2: Exploring and Analyzing Data with Pandas
#
# Objective:
#
# In this mission, you will perform Exploratory Data Analysis (EDA) and basic data manipulation using Pandas. You will work with a dataset that includes information about employees and apply various data transformation techniques, including handling missing values, filtering, and performing basic data analysis.
#
# Dataset Overview:
#
# The dataset contains the following columns:
#
# employee_id: Unique identifier for each employee.
#
# name: Name of the employee.
#
# age: Age of the employee.
#
# department: The department where the employee works (e.g., HR, Engineering, Marketing).
#
# salary: Annual salary of the employee.
#
# work_experience: Number of years of work experience the employee has.

# %% [markdown]
# ## Task 1: Load the Data
# Objective: Load the dataset into a Pandas DataFrame.
#
# Instructions:
#
# Create a DataFrame from the provided dataset.
#
# Display the first few rows of the dataset to ensure it loaded correctly.

# %%
import pandas as pd

# Create a basic dataset
data = {
    'employee_id': range(1, 21),
    'name': ['John', 'Jane', 'Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah', 'Ivy', 'Jack', 'Karen', 'Leo', 'Mia', 'Nina', 'Olivia', 'Paul', 'Quinn', 'Rita'],
    'age': [22, 25, 28, 35, 40, 42, 50, 60, 65, 30, 28, 24, 37, 41, 48, 33, 29, 32, 45, 38],
    'department': ['HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales', 'HR', 'Engineering', 'Marketing', 'Finance', 'Sales'],
    'salary': [50000, 60000, 55000, 75000, 80000, 85000, 100000, 110000, 120000, 65000, 67000, 72000, 85000, 90000, 95000, 48000, 67000, 70000, 80000, 88000],
    'work_experience': [1, 3, 5, 7, 10, 12, 15, 18, 20, 3, 1, 6, 4, 8, 5, 7, 3, 2, 6, 5],
}

df = pd.DataFrame(data)

display(df)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 87065880-987b-420e-bf1a-2862529563e1)

# %% [markdown]
# ### Task 2: Data Exploration
#
# Objective: Explore the dataset to get an understanding of its structure.
#
# Instructions:
#
# Check for missing values in the dataset.
#
# Get the summary statistics of numeric columns (age, salary, work_experience).

# %%
# Check for missing values
missing_values = df.isnull()

# Display only rows with null values
rows_with_nulls = df[missing_values.any(axis=1)]

# Display the rows with null values
display(rows_with_nulls)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 34df08f1-4b92-4a2a-a6c0-d2037b496e93)

# %%
# Stats - Age
mean_age = df['age'].mean()
median_age = df['age'].median()
mode_age = df['age'].mode()
std_age = df['age'].std()

print(f"Average Age: {mean_age} years old, Median Age: {median_age} years old, Mode: {mode_age} years old, Std Dev: {std_age}years")

# Stats - Salary
mean_salary = df['salary'].mean()
median_salary = df['salary'].median()
mode_salary = df['salary'].mode()
std_salary = df['salary'].std()

print(f"Average Salary: ${mean_salary}, Median Salary: ${median_salary}, Mode: ${mode_salary}, Std Dev: ${std_salary}")

#Stats - Work Exp
mean_workexp = df['work_experience'].mean()
median_workexp = df['work_experience'].median()
mode_workexp = df['work_experience'].mode()
std_workexp = df['work_experience'].std()

print(f"Average Work Experience: {mean_workexp} years, Median Work Experience: {median_workexp} years, Mode: {mode_workexp} years, Std Dev: {std_workexp} years")
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 6, Finished, Available, Finished, False)
# Average Age: 37.6 years old, Median Age: 36.0 years old, Mode: 0    28
# Name: age, dtype: int64 years old, Std Dev: 11.627553482998906years
# Average Salary: $78100.0, Median Salary: $77500.0, Mode: $0    67000
# 1    80000
# 2    85000
# Name: salary, dtype: int64, Std Dev: $19150.09962870882
# Average Work Experience: 7.05 years, Median Work Experience: 5.5 years, Mode: 0    3
# 1    5
# Name: work_experience, dtype: int64 years, Std Dev: 5.414162714098722 years

# %% [markdown]
# ### Task 3: Data Transformation
#
# Objective: Perform basic data transformations such as creating new columns and renaming existing ones.
#
# Instructions:
#
# Create a new column called years_to_retirement by subtracting the age from 65.
#
# Rename the salary column to annual_salary.
#
# Sort the DataFrame based on work_experience in descending order.

# %%
##Code here
# New column
df["years_to_retirement"] = 65 - df["age"]

#Rename column
df.rename(columns={'salary': 'annual_salary'}, inplace=True)

#Sort descending
sorted_df = df.sort_values(by='work_experience', ascending=False)
display(sorted_df)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c79960c4-a301-414f-bddd-0c07e7d50cbb)

# %% [markdown]
# ### Task 4: Handling Missing Data
#
# Objective: Handle missing data (if any).
#
# Instructions:
#
# Introduce some missing values in the annual_salary column.
#
# Handle the missing data by either filling it with the mean salary or dropping the rows with missing values.

# %%
#Create missing values
df.loc[df["annual_salary"] == 67000, "annual_salary"] = None

display(df)

# Check the number of rows before dropping null values
rows_before = len(df)
print(f"Number of rows before dropping nulls: {rows_before}")
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e156c7de-bafa-405f-b1a3-7ff2ea037454)
# Number of rows before dropping nulls: 20

# %%
##Code here

# Drop rows with any null values
df_cleaned = df.dropna()

# Check the number of rows after dropping null values
rows_after = len(df_cleaned)
print(f"Number of rows after dropping nulls: {rows_after}")

# Display the cleaned DataFrame
display(df_cleaned)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 9, Finished, Available, Finished, False)
# Number of rows after dropping nulls: 18
# SynapseWidget(Synapse.DataFrame, 88ad2089-b5cf-4c89-a284-b1b63c1dfbad)

# %% [markdown]
# ## Task 5: Data Filtering and Selection
# Objective: Select specific data based on conditions.
#
# Instructions:
#
# Filter the data to show only employees who are older than 30.
#
# Select only the columns name, age, and annual_salary.

# %%
##  Code here
filtered_df = df.loc[df['age'] > 30, ['name', 'age', 'annual_salary']]
display(filtered_df)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 26fc127d-92dc-4086-a3fb-ffa7698d182c)

# %% [markdown]
# ### Task 6: Data Aggregation
# Objective: Perform group-based aggregation.
#
# Instructions:
#
# Group the data by department and calculate the average salary for each department.

# %%
## Code here
avg_salary = (
    df.groupby('department')['annual_salary']
      .mean()
      .reset_index()
)

display(avg_salary)
# Out:
# StatementMeta(, 75f3b40a-f313-449a-9171-59bdcb895dec, 23, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, dda6d662-b305-4baa-bc83-27d22b88dfde)

# %% [markdown]
# Please use desribe function to show the summary of the dataframe. Moreover, use numpy library to introduce null in the dataframe using function like np.nan
